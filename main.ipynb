# %%
# %run init_project.py
# Out:
# hola

# %%
# %run notebooks/extract.ipynb

# %%
# %run notebooks/transform.ipynb

# %%
# %run notebooks/load.ipynb

# %%
df = pd.read_csv('data/rutas_excel/rutas_limpias.csv')

# %%
df.shape
# Out:
# (500, 35)

# %%
df.head()
# Out:
#    route_id        date  weekday  week_number  driver_id origin_barrio  \
# 0      2000  2025-01-27        0            4          3      La Plata
# 1      2001  2025-03-25        1           12          1        Abasto
# 2      2002  2025-01-11        5            1          3        Abasto
# 3      2003  2025-11-24        0           47          5       Berisso
# 4      2004  2025-02-12        2            6          4  Villa Elvira
#
#    lat_origin  lon_origin                          barrios_recorridos  \
# 0  -34.922486  -57.952770                            La Plata; Tolosa
# 1  -34.820862  -57.922538              Abasto; Villa Elisa; City Bell
# 2  -34.817327  -57.916802                      Abasto; Lisandro Olmos
# 3  -34.861056  -57.870459  Berisso; Los Talas; Joaquin Gorina; Gonnet
# 4  -34.893168  -57.955424                 Villa Elvira; Villa Montoro
#
#   tipo_vehiculo  ...  motivo_incidente  paquetes_no_entregados  \
# 0     Furgoneta  ...   Cliente ausente                       1
# 1     Camioneta  ...               NaN                       0
# 2     Camioneta  ...               NaN                       0
# 3     Camioneta  ...               NaN                       0
# 4     Camioneta  ...               NaN                       2
#
#    porcentaje_entregas_exitosas  prioridad  entregas_retrasadas      clima  \
# 0                         98.77      media                    1    Nublado
# 1                        100.00       alta                    0  Despejado
# 2                        100.00       baja                    0  Despejado
# 3                        100.00      media                    0  Despejado
# 4                         97.83      media                    1    Nublado
#
#     turno    estado_ruta     notas_logisticas  costo_est_operativo
# 0  mañana  con_incidente  Devolver a depósito                29.01
# 1  mañana    completa_ok                  NaN                30.33
# 2  mañana    completa_ok                  NaN                33.10
# 3  mañana    completa_ok                  NaN                35.25
# 4  mañana  con_incidente                  NaN                40.05
#
# [5 rows x 35 columns]

# %%
df['route_id']
# Out:
# 0      2000
# 1      2001
# 2      2002
# 3      2003
# 4      2004
#        ...
# 495    2495
# 496    2496
# 497    2497
# 498    2498
# 499    2499
# Name: route_id, Length: 500, dtype: int64
